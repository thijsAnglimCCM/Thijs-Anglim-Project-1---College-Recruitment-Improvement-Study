# %%
import pandas as pd

# %% [markdown]
# Importing the major and non-major surveys from fall 2024

# %%
df24_non = pd.read_csv('/Users/thijsanglim/Downloads/Non-Majors Survey Results/non-Majors2024.csv')

# %%
df24_major = pd.read_csv('/Users/thijsanglim/Downloads/Majors Survey Results/Majors Survey Results - Fall 2024.csv')

# %% [markdown]
# Questions:
# 1.Looking at the latest survey results (2024) from both the Majors and Non-Majors surveys, what are the gender demographic differences between the Majors and Non-Majors respondents?
#
# 2.Looking at the latest survey results (2024) from Non-Majors surveys, how did respondents receive information about CCM Computing programs?
#
#
# 3.Looking at the latest survey results (2024) from Non-Majors surveys, how did respondents rank how interested they were in additional CCM Computing courses?
#
#
# 4.Looking at the latest survey results (2024) from Non-Majors surveys, what current degrees are respondents enrolled in?
#
#
# 5.Looking at the latest survey results (2024) from Non-Majors surveys, which CCM Computing programs were respondents most interested in taking?

# %%
df24_non
# Out:
#                      Timestamp   Which course are you currently enrolled in?  \
# 0   2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1   2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4    2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
# ..                         ...                                           ...
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %%
df24_major
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %% [markdown]
# Reviewing column names and questions

# %%
df24_non.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]',
#        'What motivated you to seek a computing class at CCM? [To keep current in computing skills]',
#        'What motivated you to seek a computing class at CCM? [Career Advancement]',
#        'What motivated you to seek a computing class at CCM? [Career Change]',
#        'What motivated you to seek a computing class at CCM? [Professional Development]',
#        'What motivated you to seek a computing class at CCM? [Job Displacement]',
#        'What motivated you to seek a computing class at CCM? [Relocation]',
#        'What motivated you to seek a computing class at CCM? [IT Industry Certifications]',
#        'What motivated you to seek a computing class at CCM? [Financial]',
#        'What motivated you to seek a computing class at CCM? [Personal Enrichment]',
# ...

# %%
df24_major.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# Renaming columns

# %%
df24_non.rename(columns={'Timestamp':'time', 'Which course are you currently enrolled in?':'current_course',
       'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]':'required_class',
       'What motivated you to seek a computing class at CCM? [To keep current in computing skills]':'keep_current',
       'What motivated you to seek a computing class at CCM? [Career Advancement]':'advancement',
       'What motivated you to seek a computing class at CCM? [Career Change]':'career_change',
       'What motivated you to seek a computing class at CCM? [Professional Development]':'professional_development',
       'What motivated you to seek a computing class at CCM? [Job Displacement]':'job_displacement',
       'What motivated you to seek a computing class at CCM? [Relocation]':'relocation',
       'What motivated you to seek a computing class at CCM? [IT Industry Certifications]':'industry_certification',
       'What motivated you to seek a computing class at CCM? [Financial]':'financial',
       'What motivated you to seek a computing class at CCM? [Personal Enrichment]':'enrichment',
       'What motivated you to seek a computing class at CCM? [Curiosity]':'curiousity',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]':'open_house',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]':'instant_decision',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]':'campus_session',
       "Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [TItan's Tuesday Virtual Information Session]":'virtual_session',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]':'woman_dare',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]':'college_fair',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]':'computing_class',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]':'computing_club',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]':'competitions',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]':'afterschool',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]':'camp',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]':'ap_class',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]':'dual_enrollment',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]':'person',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]':'computing_field_person',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]':'extent_counselor',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]':'extent_employer',
       'How did you hear about County College of Morris  [CCM Web site]':'hear_website',
       'How did you hear about County College of Morris  [Billboard]':'hear_billboard',
       'How did you hear about County College of Morris  [Television]':'hear_television',
       'How did you hear about County College of Morris  [Radio]':'hear_radio',
       'How did you hear about County College of Morris  [Social Media]':'hear_media',
       'How did you hear about County College of Morris  [Community Event]':'hear_community',
       'How did you hear about County College of Morris  [Family member or friend]':'hear_person',
       'How did you hear about County College of Morris  [Employer]':'hear_employer',
       'How did you hear about County College of Morris  [Current student]':'hear_current_student',
       'How did you hear about County College of Morris  [Alumni]':'hear_alumni',
       'How did you hear about County College of Morris  [High School]':'hear_high_school',
       'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]':'affordable',
       'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]':'location',
       'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]':'choices',
       'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]':'online_offers',
       'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]':'referral',
       'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]':'faculty',
       'To what extent did the following impact your decision to attend County College of Morris? [College reputation]':'reputation',
       'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]':'scholarships',
       'To what extent did the following impact your decision to attend County College of Morris? [Transfer student]':'transfer',
       'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]':'small_size',
       'To what extent did the following impact your decision to attend County College of Morris? [Extra curricula opportunities]':'extra_curricula',
       'What degree program are you currently enrolled in?':'degree_program',
       'Did you receive information about our computing course from any of the following sources? [High school guidance counselor]':'source_counselor',
       'Did you receive information about our computing course from any of the following sources? [CCM Information Technologies Website]':'source_website',
       'Did you receive information about our computing course from any of the following sources? [CCM Admissions]':'source_admissions',
       'Did you receive information about our computing course from any of the following sources? [CCM advisor/counselor]':'source_advisor',
       'Did you receive information about our computing course from any of the following sources? [Employer]':'source_employer',
       'Did you receive information about our computing course from any of the following sources? [Other]':'source_other',
       'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?':'scale_interest',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Web Development]':'interest_web',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [CyberSecurity]':'interest_cybersecurity',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [App Development]':'interest_apps',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Data Analytics]':'interest_analytics',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Machine Learning/Artificial Intelligence]':'interest_ai',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Computer Programming]':'interest_programming',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Game Design]':'interest_games',
       'If you answered that you were interested in taking more computing classes, which ones interest you most? [Hardware Installation & Repair]':'interest_hardware',
       'Gender':'gender', 'Race/ethnicity':'race', 'Age ':'age'}, inplace = True)

# %%
df24_non
# Out:
#                           time                                current_course  \
# 0   2024/09/10 10:47:35 AM AST  CMP 126 Computer Technology and Applications
# 1   2024/09/10 11:00:05 AM AST  CMP 126 Computer Technology and Applications
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# 4    2024/09/10 8:37:36 PM AST         CMP 101 Computer Information Literacy
# ..                         ...                                           ...
# 87  2024/09/20 10:55:34 PM AST         CMP 101 Computer Information Literacy
# 88  2024/09/20 11:02:45 PM AST  CMP 126 Computer Technology and Applications
# 89  2024/09/20 11:07:16 PM AST  CMP 126 Computer Technology and Applications
# 90   2024/09/21 5:06:23 PM AST         CMP 101 Computer Information Literacy
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %%
df24_non.columns
# Out:
# Index(['time', 'current_course', 'required_class', 'keep_current',
#        'advancement', 'career_change', 'professional_development',
#        'job_displacement', 'relocation', 'industry_certification', 'financial',
#        'enrichment', 'curiousity', 'open_house', 'instant_decision',
#        'campus_session', 'virtual_session', 'woman_dare', 'college_fair',
#        'computing_class', 'computing_club', 'competitions', 'afterschool',
#        'camp', 'ap_class', 'dual_enrollment', 'person',
#        'computing_field_person', 'extent_counselor', 'extent_employer',
#        'hear_website', 'hear_billboard', 'hear_television', 'hear_radio',
#        'hear_media', 'hear_community', 'hear_person', 'hear_employer',
#        'hear_current_student', 'hear_alumni', 'hear_high_school', 'affordable',
#        'location', 'choices', 'online_offers', 'referral', 'faculty',
#        'reputation', 'scholarships', 'transfer', 'small_size',
# ...

# %%
df24_major.rename(columns={'Timestamp':'time', 'Which course are you enrolled in?':'current_course',
       'How did you hear about County College of Morris? [CCM Web site]':'hear_website',
       'How did you hear about County College of Morris? [Social Media]':'hear_media',
       'How did you hear about County College of Morris? [Community Event]':'hear_community',
       'How did you hear about County College of Morris? [Family member or friend]':'hear_person',
       'How did you hear about County College of Morris? [Current CCM student]':'hear_current_student',
       'How did you hear about County College of Morris? [CCM Alumni]':'hear_alumni',
       'How did you hear about County College of Morris? [High School Teacher]':'hear_hs_teacher',
       'How did you hear about County College of Morris? [High School Counselor]':'hear_hs_counselor',
       'How did you hear about County College of Morris? [In-app advertisement]':'hear_advertisement',
       'How did you hear about County College of Morris? [Employer]':'hear_employer',
       'How did you hear about County College of Morris? [Billboard]':'hear_billboard',
       'How did you hear about County College of Morris? [Television]':'hear_television',
       'How did you hear about County College of Morris? [Radio]':'hear_radio',
       'How did you hear about County College of Morris? [Other]':'hear_other',
       'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]':'affordable',
       'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]':'location',
       'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]':'choices',
       'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]':'online_offers',
       'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]':'referral',
       'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]':'faculty',
       'To what extent did the following impact your decision to attend County College of Morris? [College reputation]':'reputation',
       'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]':'financial_aid',
       'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]':'scholarships',
       'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]':'small_size',
       'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]':'extra_curricula',
       'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]':'accept_transfer_credits',
       'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]':'negative_experiences',
       'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]':'nj_stars',
       'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]':'ability_to_transfer',
       'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]':'credit_in_hs',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]':'open_house',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]':'instant_decision',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]':'campus_session',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]':'virtual_session',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]':'women_dare',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]':'college_fair',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]':'sharetime_session',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]':'challenger_program',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]':'protection_program',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]':'hs_session',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]':'hs_campus_visit',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]':'individual_campus_visit',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]':'development_class',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]':'training',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]':'teen_arts',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]':'ccm_camp',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]':'computing_class',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]':'computing_club',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]':'competitions',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]':'afterschool',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]':'camp',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]':'ap_class',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]':'dual_enrollment',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]':'person',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]':'person_computing_field',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]':'extent_counselor',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]':'extent_employer',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]':'extent_current_student',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]':'work_experience',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]':'extent_other',
       'What degree program are you currently enrolled in?':'degree_program',
       'What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]':'job_motivation',
       "What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor's level program]": 'transfer_bachelors',
       'What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]':'hs_credit_transfer',
       'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]':'advancement',
       'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]':'career_change',
       'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]':'development',
       'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]':'job_displacement',
       'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]':'relocation',
       'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]':'keep_current',
       'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]':'industry_certification',
       'What motivated you to seek a computing degree/certificate at CCM?  [Financial]':'financial',
       'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]':'enrichment',
       'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]':'source_counselor',
       'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]':'source_teacher',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]':'source_website',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]':'source_admissions',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]':'source_advisor',
       'Did you receive information about the CCM computing programs from any of the following sources? [Employer]':'source_employer',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]':'source_workforce_development',
       'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]':'source_development_program',
       'Did you receive information about the CCM computing programs from any of the following sources? [Other]':'source_other',
       'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.':'initial_major',
       'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?':'scale_interest',
       'Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?':'interest_response',
       'Gender':'gender', 'Race/ethnicity':'race', 'Age ':'age'},inplace=True)

# %%
df24_major
# Out:
#                            time                                current_course  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %%
df24_major.columns
# Out:
# Index(['time', 'current_course', 'hear_website', 'hear_media',
#        'hear_community', 'hear_person', 'hear_current_student', 'hear_alumni',
#        'hear_hs_teacher', 'hear_hs_counselor', 'hear_advertisement',
#        'hear_employer', 'hear_billboard', 'hear_television', 'hear_radio',
#        'hear_other', 'affordable', 'location', 'choices', 'online_offers',
#        'referral', 'faculty', 'reputation', 'financial_aid', 'scholarships',
#        'small_size', 'extra_curricula', 'accept_transfer_credits',
#        'negative_experiences', 'nj_stars', 'ability_to_transfer',
#        'credit_in_hs', 'open_house', 'instant_decision', 'campus_session',
#        'virtual_session', 'women_dare', 'college_fair', 'sharetime_session',
#        'challenger_program', 'protection_program', 'hs_session',
#        'hs_campus_visit', 'individual_campus_visit', 'development_class',
#        'training', 'teen_arts', 'ccm_camp', 'computing_class',
# ...

# %% [markdown]
# Question: Looking at the latest survey results (2024) from both the Majors and Non-Majors surveys, what are the gender demographic differences between the Majors and Non-Majors respondents?

# %%
df24_non.columns
# Out:
# Index(['time', 'current_course', 'required_class', 'keep_current',
#        'advancement', 'career_change', 'professional_development',
#        'job_displacement', 'relocation', 'industry_certification', 'financial',
#        'enrichment', 'curiousity', 'open_house', 'instant_decision',
#        'campus_session', 'virtual_session', 'woman_dare', 'college_fair',
#        'computing_class', 'computing_club', 'competitions', 'afterschool',
#        'camp', 'ap_class', 'dual_enrollment', 'person',
#        'computing_field_person', 'extent_counselor', 'extent_employer',
#        'hear_website', 'hear_billboard', 'hear_television', 'hear_radio',
#        'hear_media', 'hear_community', 'hear_person', 'hear_employer',
#        'hear_current_student', 'hear_alumni', 'hear_high_school', 'affordable',
#        'location', 'choices', 'online_offers', 'referral', 'faculty',
#        'reputation', 'scholarships', 'transfer', 'small_size',
# ...

# %%
df24_major.columns
# Out:
# Index(['time', 'current_course', 'hear_website', 'hear_media',
#        'hear_community', 'hear_person', 'hear_current_student', 'hear_alumni',
#        'hear_hs_teacher', 'hear_hs_counselor', 'hear_advertisement',
#        'hear_employer', 'hear_billboard', 'hear_television', 'hear_radio',
#        'hear_other', 'affordable', 'location', 'choices', 'online_offers',
#        'referral', 'faculty', 'reputation', 'financial_aid', 'scholarships',
#        'small_size', 'extra_curricula', 'accept_transfer_credits',
#        'negative_experiences', 'nj_stars', 'ability_to_transfer',
#        'credit_in_hs', 'open_house', 'instant_decision', 'campus_session',
#        'virtual_session', 'women_dare', 'college_fair', 'sharetime_session',
#        'challenger_program', 'protection_program', 'hs_session',
#        'hs_campus_visit', 'individual_campus_visit', 'development_class',
#        'training', 'teen_arts', 'ccm_camp', 'computing_class',
# ...

# %% [markdown]
# Sorting the data frames by gender

# %%
df24_non.sort_values('gender', inplace = True)

# %%
df24_major.sort_values('gender', inplace = True)

# %% [markdown]
# After giving each column simpler names, I am removing columns for irrelevant topics.
# The relevant topics are gender,sources of reach,numerical scale of interest, interests in specific programs and current degree course.
#
# The majors course only needs the gender column because I am only using it for gender demographics

# %%
df24_major_gender = df24_major.loc[:,'gender']

# %% [markdown]
# I seperated the gender column from the 2024 majors survey using the loc function.

# %%
df24_major_gender
# Out:
# 0        Man
# 121      Man
# 122      Man
# 125      Man
# 126      Man
#        ...
# 123    Woman
# 124    Woman
# 153    Woman
# 177    Woman
# 104    Woman
# Name: gender, Length: 197, dtype: object

# %%
df24_non.drop(columns = ['required_class', 'keep_current',
       'advancement', 'career_change', 'professional_development',
       'job_displacement', 'relocation', 'industry_certification', 'financial',
       'enrichment', 'curiousity', 'open_house', 'instant_decision',
       'campus_session', 'virtual_session', 'woman_dare', 'college_fair',
       'computing_class', 'computing_club', 'competitions', 'afterschool',
       'camp', 'ap_class', 'dual_enrollment', 'person',
       'computing_field_person', 'extent_counselor', 'extent_employer', 'affordable',
       'location', 'choices', 'online_offers', 'referral', 'faculty',
       'reputation', 'scholarships', 'transfer', 'small_size',
       'extra_curricula', 'degree_program', 'source_counselor',
       'source_website', 'source_admissions', 'source_advisor',
       'source_employer', 'source_other','race', 'age'],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df24_non.drop(columns = ['required_class', 'keep_current',
#       2        'advancement', 'career_change', 'professional_development',
#       3        'job_displacement', 'relocation', 'industry_certification', 'financial',
#       4        'enrichment', 'curiousity', 'open_house', 'instant_decision',
#       5        'campus_session', 'virtual_session', 'woman_dare', 'college_fair',
#       6        'computing_class', 'computing_club', 'competitions', 'afterschool',
#       7        'camp', 'ap_class', 'dual_enrollment', 'person',
#       8        'computing_field_person', 'extent_counselor', 'extent_employer', 'affordable',
#       9        'location', 'choices', 'online_offers', 'referral', 'faculty',
#      10        'reputation', 'scholarships', 'transfer', 'small_size',
# ...

# %% [markdown]
# I used the drop function on the 2024 non-majors survey to get rid of columns that were not helpful for my research questions.

# %%
df24_non
# Out:
#                           time                                current_course  \
# 27  2024/09/12 11:32:08 AM AST   CMP 135 Computer Concepts with Applications
# 33  2024/09/12 12:41:01 PM AST         CMP 101 Computer Information Literacy
# 53  2024/09/16 12:12:48 PM AST         CMP 101 Computer Information Literacy
# 2   2024/09/10 11:02:51 AM AST  CMP 126 Computer Technology and Applications
# 3   2024/09/10 11:05:25 AM AST  CMP 126 Computer Technology and Applications
# ..                         ...                                           ...
# 45   2024/09/12 8:06:05 PM AST   CMP 135 Computer Concepts with Applications
# 54  2024/09/16 12:33:11 PM AST  CMP 126 Computer Technology and Applications
# 20  2024/09/12 11:30:41 AM AST   CMP 135 Computer Concepts with Applications
# 16  2024/09/12 11:30:18 AM AST   CMP 135 Computer Concepts with Applications
# 91  2024/09/22 10:08:19 PM AST  CMP 126 Computer Technology and Applications
#
# ...

# %% [markdown]
# Checking the data to make sure I can extract proper numerical data from it

# %%
df24_major_gender.value_counts()
# Out:
# gender
# Man                  162
# Woman                 33
# Prefer not to say      2
# Name: count, dtype: int64

# %%
df24_non['gender'].value_counts()
# Out:
# gender
# Woman                60
# Man                  29
# Prefer not to say     2
# Non-binary            1
# Name: count, dtype: int64

# %%
df24_non['current_course'].value_counts()
# Out:
# current_course
# CMP 135 Computer Concepts with Applications     40
# CMP 126 Computer Technology and Applications    30
# CMP 101 Computer Information Literacy           22
# Name: count, dtype: int64

# %% [markdown]
# Downloading the files for part 3

# %%
df24_non.to_csv('df24_non.csv', index=False)

# %%
df24_major_gender.to_csv('df24_major_gender.csv',index = False)
